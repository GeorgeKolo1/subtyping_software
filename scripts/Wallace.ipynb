# %%
import numpy as np

# %%
def Wallace(arr1, arr2):
    if isinstance(arr1, np.array) == False or isinstance(arr2, pd.np.array) == False:
        raise TypeError("Input arrays must not be pandas DataFrames, provide numpy array.")

    # Compute the Wallace transform
   def CT:
    ''' Compute the contingency table for the wallace coefficient'''

    return Wab

# %%
Wallace()
